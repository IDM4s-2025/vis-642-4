# %%
import pandas as pd
import grafics as plt

# %%
path = "C:/Users/dilos/OneDrive/Documents/GitHub/vis-642-4/better life/OECD,DF_BLI,+all.csv"
table = plt.load_data(path)

# %%
plt.get_corelation(table,(15.0,8.0))

# %%
plt.ploly_sactter(table,"HO_BASE","HS_LEB")

# %%
plt.ploly_sactter(table,"JE_PEARN","IW_HADI")

# %%
plt.ploly_sactter(table,"ES_EDUEX","ES_STCS")

# %%
plt.ploly_sactter(table,"EQ_WATER","HS_LEB")
plt.ploly_sactter(table,"EQ_AIRP","HS_LEB")

# %%
plt.ploly_sactter(table,"JE_PEARN","SW_LIFS")
plt.ploly_sactter(table,"SC_SNTWS","SW_LIFS")
plt.ploly_sactter(table,"HS_SFRH","SW_LIFS")
plt.ploly_sactter(table,"JE_PEARN","SW_LIFS")
